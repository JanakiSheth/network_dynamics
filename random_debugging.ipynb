# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111)

t = np.arange(11)

for i in range(10):
    line, = ax.plot(t,i*(t+1), linestyle = '-')
    ax.plot(t,i*(t+1)+.3,color = line.get_color(), linestyle = ':')

plt.show()

# %%
# Initially check analysis with good neurons
"""
# MT068_20190830
neurons_with_fr_and_Ca_response = np.array([2,3,4,6,15,17,18,19,20,22,28,29,31,34,38,40,41,42,49,57,60,61,64,66,\
                                           70,74,75,76,78,79,81,82,83,87,89,90,94,109,119,128,137,138,139,140,141,\
                                           143,144,162,166,168,169,171,172,173,175,177,178,180,185,187,190,191,\
                                            196,201,148,126,121,117,102,100,95,86,85,68,65,62,58,54,51,\
                                           39,36,35,32,25,24,12,11,10,0])
best_neurons_with_fr_and_Ca_response = np.array([17,18,22,31,41,61,70,74,83,89,90,137,166,168,51,58,95,100])


# MT065_20190903
neurons_with_fr_and_Ca_response = np.array([4,5,6,8,9,11,12,13,16,18,19,21,22,24,26,27,28,30,32,33,34,35,36,\
                                           37,40,42,43,44,48,49,50,54,56,59,60,67,68,69,71,72,73,76,79,80,81,82,\
                                            83,84,86,88,91,92,93,95,96,101,103,104,105,111,117,119,124,126,130,\
                                           133,139,145,149,150,151,153,164,167,168,169,179,180,183,184,192,\
                                            195,201,212,214,215])
best_neurons_with_fr_and_Ca_response = np.array([])

# MT067_20190827
neurons_with_fr_and_Ca_response = np.array([3,5,6,7,8,9,10,12,14,16,17,19,22,23,24,25,26,29,30,33,36,38,39,41,\
                                           43,45,46,47,48,49,51,52,54,62,63,64,65,66,67,68,72,73,76,80,81,82,84,\
                                           85,87,88,89,90,92,97,98,100,101,109,110,111,113,116,121,122,123,124,\
                                           126,132,133,135,138,141,147,152,155,156,158,162,164,166,167,170,171,\
                                            173,175,178,181,189,192,193,199,200,203,205,212,213,217,218,219,220,\
                                           227])

# MT067_20190903
neurons_with_fr_and_Ca_response = np.array([3,6,7,10,11,15,17,20,25,26,28,29,37,38,39,41,42,43,44,45,46,47,51,54,\
                                           55,62,64,65,70,71,73,74,76,79,80,82,84,89,91,93,94,100,102,108,110,112,\
                                            118,121,126,142,150,151,153,156,159,160,163,166,177,188,175,177,185,\
                                            188,189,190,194,203,212,214,216,221,230,231,235,253,263,267,272,286])
best_neurons_with_fr_and_Ca_response = np.array([17,20,37,47,64,73,76,82,89,100,108,110,112,126,175,185,189,\
                                              214,231])

# MT062_20190825
neurons_with_fr_and_Ca_response =  np.array([5,6,7,8,16,20,22,23,25,28,29,31,35,37,38,47,49,51,52,54,55,60,64,\
                                             65,67,69,72,74,84,85,99,100,103,105,108,111,112,118,124,129,133,\
                                             147,151,163,166,173,174,179,197,205,206,214,215,264])

# MT063_20190909
neurons_with_fr_and_Ca_response =  np.array([4,8,15,17,28,29,33,34,39,43,56,71,74,75,79,80,88,94,114,124,127,144,\
                                            184])
"""
# MT063_20190829
neurons_with_fr_and_Ca_response =  np.array([3,7,10,11,23,27,32,34,41,42,43,45,46,48,50,54,61,88,90,\
                                             112,116,117,125,129,146,160])
